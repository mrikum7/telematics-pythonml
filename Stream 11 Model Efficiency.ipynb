# %%
from sklearn.datasets import make_blobs
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
import mglearn

# %%
X, y = make_blobs()

# %%
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
# Out:
# [<matplotlib.lines.Line2D at 0x7f51263b0750>,
#  <matplotlib.lines.Line2D at 0x7f51263a7b50>,
#  <matplotlib.lines.Line2D at 0x7f51263a7750>]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                    y, 
                                    test_size = 0.2, 
                                    random_state = 20)

# %%
from sklearn.neighbors import KNeighborsClassifier
from matplotlib import pyplot as plt
from sklearn import svm
from sklearn import naive_bayes

# %%
clf = KNeighborsClassifier(n_neighbors=1) ##Classifier Object

# %%
clf = svm.SVC()

# %%
clf = naive_bayes.GaussianNB()

# %%
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
X.shape
# Out:
# (100, 2)

# %%
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
mglearn.plots.plot_2d_separator(clf, X_train,
                                fill = True,
                                eps = 0.5,  
                                alpha = 0.4)

# %%
X, y = make_regression(n_samples = 100, 
                       n_features = 2)

# %%
plt.scatter(X[:,1], y)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
reg = KNeighborsRegressor(n_neighbors=3)

# %%
reg.fit(X[:,0].reshape(-1, 1), y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform')
